# %%
import sys
import os
import torch
import cv2 as cv
import numpy as np
import torchvision
from torch import nn, optim
import torch.nn.functional as F
import torch.utils.data
import torchvision.datasets as dset
import torchvision.utils as vutils
from torch.utils.data import DataLoader
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import random
from torch.utils.data.sampler import SubsetRandomSampler
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Using GPU
print(sys.version)
device = 'cuda'
#Checking for GPU
print(torch.version.cuda)
print(torch.cuda.device_count())
print(torch.cuda.is_available())
# Out:
# 3.6.9 (default, Apr 18 2020, 01:56:04)
# [GCC 8.4.0]
# 10.1
# 1
# True

# %%
lookup = dict()
reverselookup = dict()

count = 0

for j in os.listdir('drive/My Drive/Colab Notebooks/ITSP/mydata/'):
    if not j.startswith('.'):
        lookup[j] = count
        reverselookup[count] = j
        count += 1
        
print(lookup)
print(reverselookup)
# Out:
# {'3': 0, '6': 1, '4': 2, '2': 3, '1': 4, '7': 5, '5': 6, '8': 7, '0': 8, '9': 9}
# {0: '3', 1: '6', 2: '4', 3: '2', 4: '1', 5: '7', 6: '5', 7: '8', 8: '0', 9: '9'}

# %%
x_data = []
y_data = []
datacount = 0
image_size = 256

dataset = dset.ImageFolder(root = 'drive/My Drive/Colab Notebooks/ITSP/mydata', 
                transform = 
                transforms.Compose([
                transforms.Resize(image_size),
                transforms.RandomResizedCrop(size=256, scale=(0.95, 1.0)),
                transforms.RandomRotation(degrees=10),
                transforms.ColorJitter(),
                transforms.RandomHorizontalFlip(0.3),
                transforms.Resize(size=224),  # Image net standards
                transforms.ToTensor(),
                transforms.Normalize([0.485, 0.456, 0.406],
                                     [0.229, 0.224, 0.225])  # Imagenet standards
                #transforms.ToTensor(), 
                #transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                ]))

print(dataset)

batch = 16
random_seed = random.randint(1, 100)

dataset_size = len(dataset)
split = int(0.05*dataset_size)
print('Size of dataset is: ', dataset_size)
print('Split value: ', split)
indices = list(range(dataset_size))

np.random.seed(random_seed)
np.random.shuffle(indices)

train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch, sampler=train_sampler,
                                            num_workers = 2)
valid_loader = torch.utils.data.DataLoader(dataset, batch_size=batch, sampler=valid_sampler,
                                            num_workers = 2)

print(len(train_loader))
print(len(valid_loader))


#for image, label in train_loader:
    #print(label)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 3535
#     Root location: drive/My Drive/Colab Notebooks/ITSP/mydata
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=PIL.Image.BILINEAR)
#                RandomResizedCrop(size=(256, 256), scale=(0.95, 1.0), ratio=(0.75, 1.3333), interpolation=PIL.Image.BILINEAR)
#                RandomRotation(degrees=(-10, 10), resample=False, expand=False)
#                ColorJitter(brightness=None, contrast=None, saturation=None, hue=None)
#                RandomHorizontalFlip(p=0.3)
#                Resize(size=224, interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# Size of dataset is:  3535
# Split value:  176
# 210
# 11

# %%
# Iterate through the dataloader once
trainiter = iter(train_loader)
features, labels = next(trainiter)
features.shape, labels.shape
# Out:
# (torch.Size([16, 3, 224, 224]), torch.Size([16]))

# %%
def get_image_shape():
    img = cv.imread('drive/My Drive/Colab Notebooks/ITSP/mydata/1/1.jpg', 0)
    return img.shape


img_shape = get_image_shape()
print('Image shape: ', img_shape)
root = 'drive/My Drive/Colab Notebooks/ITSP/mydata'
gesture_data = os.listdir(root)
num_g = len(gesture_data)
print('Number of gestures: ', num_g)
num_rows = int(num_g/4)

if(num_g%4):
   num_rows+=1

print('Number of rows: ', num_rows)

begin = 0
final_img = None

for i in range(num_rows):
    row_img = None
    for j in range(begin, begin+4):
        if (j>= num_g):
            img = np.zeros(img_shape, dtype = np.uint8)
            #print('Image index: ', j, 'false')
            
        else:         
            imgpath = root + '/' + reverselookup[j] + '/' + str(random.randint(1, 200)) + '.jpg'
            img = cv.imread(imgpath, 0)
            #if not np.any(img == None):
                #print('Image index: ', j, 'true')
            
        if np.any(row_img == None):
            row_img = img
        else:
            row_img = np.hstack((row_img, img))
            
    begin += 4
    if np.any(final_img == None):
            final_img = row_img
    else:
        final_img = np.vstack((final_img, row_img))  
                        
plt.imshow(final_img, cmap='gray')
#cv.waitKey(0)
#cv.destroyAllWindows()
# Out:
# Image shape:  (256, 256)
# Number of gestures:  10
# Number of rows:  3

# %%
gestures = []
titles = []

for i in range(num_g):
    imgpath = root + '/' + reverselookup[i] + '/' + str(random.randint(1, 200)) + '.jpg'
    img = cv.imread(imgpath, 0)
    gestures.append(img)
    titles.append(reverselookup[i])
    
for i in range(num_g):
    plt.subplot(3, 4, i+1)
    plt.imshow(gestures[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

# %%
from torchvision import models
model = models.googlenet(pretrained=True)
for param in model.parameters():
    param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/checkpoints/googlenet-1378be20.pth
# HBox(children=(FloatProgress(value=0.0, max=52147035.0), HTML(value='')))

# %%
torch.save(model, 'drive/My Drive/Colab Notebooks/ITSP/googlenet.pth')
print(model)
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=1000, bias=True)
# )

# %%
n_classes = 10

model.fc = nn.Sequential(
                      nn.Linear(1024, 512), 
                      nn.ReLU(), 
                      nn.Linear(512, 256), 
                      nn.ReLU(),
                      nn.Dropout(0.2), 
                      nn.Linear(256, n_classes),                   
                      nn.LogSoftmax(dim=1))

print(model)
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Dropout(p=0.2, inplace=False)
#     (5): Linear(in_features=256, out_features=10, bias=True)
#     (6): LogSoftmax()
#   )
# )

# %%
total_params = sum(p.numel() for p in model.parameters())

print(f'{total_params:,} total parameters')

total_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'{total_trainable:,} trainable parameters.')
# Out:
# 6,258,602 total parameters
# 658,698 trainable parameters.

# %%
# Move to gpu
model = model.to('cuda')
# Distribute across 2 gpus
model = nn.DataParallel(model)

loss_func = F.cross_entropy
optimizer = optim.Adam(model.parameters(), betas=(0.5, 0.99), lr = 0.002)

# %%
def accuracy(out, yb):
    pred = torch.argmax(out, keepdim= False, dim=1)
    return (pred == yb).float().mean()

# %%
def fit(model, epochs, train_loader, valid_loader, opt):
    losses = []
    
    for epoch in range(epochs):
        train_loss =0
        train_acc =0
        model.train()
        for xb, yb in train_loader:
            xb =xb.to(device)
            yb = yb.to(device)
            pred = model(xb.float())
            pred.to(device)
            train_acc += accuracy(pred, yb)
            loss = loss_func(pred, yb)
            train_loss += loss
            #back propogation
            loss.backward()
            opt.step()
            opt.zero_grad()      

        losses.append(train_loss)
        print("Iteration no: "+ str(epoch), "loss = "+str(losses[epoch].item()))
        print("Accuracy of train set:", train_acc/len(train_loader))
        lr_scheduler.step(train_loss/len(train_loader))
        
        
        model.eval()    
        with torch.no_grad():
            valid_acc=0
            loss_valid = 0
            for xb_valid, yb_valid in valid_loader:
                xb_valid = xb_valid.to(device)
                yb_valid = yb_valid.to(device)
                pred_valid = model(xb_valid.float())
                pred_valid.to(device)
                valid_acc += accuracy(pred_valid, yb_valid)
                loss_valid += loss_func(pred_valid, yb_valid)
            print("Accuracy of validation set :", valid_acc/len(valid_loader))
            #callbacks = [EarlyStopping(monitor='valid_acc', verbose=False, mode='max', patience=10)]

    plt.plot(losses)
    plt.ylabel("loss")
    plt.xlabel("iterations")
    plt.show()

# %%
#model.set_callbacks(callbacks)

lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=4, verbose=True, eps = 10e-14)

# %%
fit(model, 120, train_loader, valid_loader, optimizer)
# Out:
# Iteration no: 0 loss = 299.4829406738281
# Accuracy of train set: tensor(0.4736, device='cuda:0')
# Accuracy of validation set : tensor(0.6477, device='cuda:0')
# Accuracy of validation set : tensor(0.7898, device='cuda:0')
# Iteration no: 2 loss = 153.0208282470703
# Accuracy of train set: tensor(0.7466, device='cuda:0')
# Accuracy of validation set : tensor(0.7614, device='cuda:0')
# Iteration no: 3 loss = 145.94361877441406
# Accuracy of train set: tensor(0.7567, device='cuda:0')
# Accuracy of validation set : tensor(0.8523, device='cuda:0')
# Iteration no: 4 loss = 124.38799285888672
# Accuracy of train set: tensor(0.7886, device='cuda:0')
# Accuracy of validation set : tensor(0.8750, device='cuda:0')
# Iteration no: 5 loss = 127.52510833740234
# Accuracy of train set: tensor(0.7860, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 6 loss = 126.9880599975586
# Accuracy of train set: tensor(0.7853, device='cuda:0')
# Accuracy of validation set : tensor(0.8523, device='cuda:0')
# Iteration no: 7 loss = 119.88186645507812
# Accuracy of train set: tensor(0.8021, device='cuda:0')
# Accuracy of validation set : tensor(0.8920, device='cuda:0')
# Iteration no: 8 loss = 118.96636962890625
# Accuracy of train set: tensor(0.8011, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 9 loss = 109.50016021728516
# Accuracy of train set: tensor(0.8199, device='cuda:0')
# Accuracy of validation set : tensor(0.8523, device='cuda:0')
# Iteration no: 10 loss = 115.27246856689453
# Accuracy of train set: tensor(0.8080, device='cuda:0')
# Accuracy of validation set : tensor(0.8864, device='cuda:0')
# Iteration no: 11 loss = 106.66088104248047
# Accuracy of train set: tensor(0.8202, device='cuda:0')
# Accuracy of validation set : tensor(0.8693, device='cuda:0')
# Iteration no: 12 loss = 104.52823638916016
# Accuracy of train set: tensor(0.8211, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 13 loss = 107.05319213867188
# Accuracy of train set: tensor(0.8211, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 14 loss = 110.15006256103516
# Accuracy of train set: tensor(0.8189, device='cuda:0')
# Accuracy of validation set : tensor(0.8864, device='cuda:0')
# Iteration no: 15 loss = 110.54142761230469
# Accuracy of train set: tensor(0.8229, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 16 loss = 104.77482604980469
# Accuracy of train set: tensor(0.8270, device='cuda:0')
# Accuracy of validation set : tensor(0.8693, device='cuda:0')
# Iteration no: 17 loss = 100.68006134033203
# Accuracy of train set: tensor(0.8395, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 18 loss = 97.82682800292969
# Accuracy of train set: tensor(0.8390, device='cuda:0')
# Accuracy of validation set : tensor(0.8693, device='cuda:0')
# Iteration no: 19 loss = 105.13458251953125
# Accuracy of train set: tensor(0.8381, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 20 loss = 101.91531372070312
# Accuracy of train set: tensor(0.8320, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 21 loss = 99.52649688720703
# Accuracy of train set: tensor(0.8425, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 22 loss = 102.17183685302734
# Accuracy of train set: tensor(0.8348, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 23 loss = 99.72806549072266
# Accuracy of train set: tensor(0.8387, device='cuda:0')
# Epoch    24: reducing learning rate of group 0 to 2.0000e-04.
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 24 loss = 80.20860290527344
# Accuracy of train set: tensor(0.8729, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 25 loss = 76.8727035522461
# Accuracy of train set: tensor(0.8735, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 26 loss = 80.08922576904297
# Accuracy of train set: tensor(0.8663, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 27 loss = 77.34455871582031
# Accuracy of train set: tensor(0.8744, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 28 loss = 80.39375305175781
# Accuracy of train set: tensor(0.8711, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 29 loss = 77.62146759033203
# Accuracy of train set: tensor(0.8684, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 30 loss = 73.61254119873047
# Accuracy of train set: tensor(0.8791, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 31 loss = 77.25820922851562
# Accuracy of train set: tensor(0.8711, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 32 loss = 81.32194519042969
# Accuracy of train set: tensor(0.8666, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 33 loss = 73.42182159423828
# Accuracy of train set: tensor(0.8800, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 34 loss = 75.17044067382812
# Accuracy of train set: tensor(0.8759, device='cuda:0')
# Accuracy of validation set : tensor(0.9773, device='cuda:0')
# Iteration no: 35 loss = 77.3089828491211
# Accuracy of train set: tensor(0.8746, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 36 loss = 72.97238159179688
# Accuracy of train set: tensor(0.8768, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 37 loss = 70.39252471923828
# Accuracy of train set: tensor(0.8866, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 38 loss = 72.10675048828125
# Accuracy of train set: tensor(0.8798, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 39 loss = 78.86869812011719
# Accuracy of train set: tensor(0.8711, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 40 loss = 71.85711669921875
# Accuracy of train set: tensor(0.8839, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 41 loss = 69.97954559326172
# Accuracy of train set: tensor(0.8863, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 42 loss = 79.87781524658203
# Accuracy of train set: tensor(0.8732, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 43 loss = 74.08842468261719
# Accuracy of train set: tensor(0.8806, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 44 loss = 74.67328643798828
# Accuracy of train set: tensor(0.8716, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 45 loss = 69.51367950439453
# Accuracy of train set: tensor(0.8851, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 46 loss = 74.08182525634766
# Accuracy of train set: tensor(0.8764, device='cuda:0')
# Accuracy of validation set : tensor(0.9773, device='cuda:0')
# Iteration no: 47 loss = 75.33370208740234
# Accuracy of train set: tensor(0.8830, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 48 loss = 70.5510025024414
# Accuracy of train set: tensor(0.8839, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 49 loss = 76.12030792236328
# Accuracy of train set: tensor(0.8779, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 50 loss = 71.09769439697266
# Accuracy of train set: tensor(0.8809, device='cuda:0')
# Epoch    51: reducing learning rate of group 0 to 2.0000e-05.
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 51 loss = 65.65216064453125
# Accuracy of train set: tensor(0.8895, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 52 loss = 67.71694946289062
# Accuracy of train set: tensor(0.8917, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 53 loss = 64.9664535522461
# Accuracy of train set: tensor(0.8904, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 54 loss = 70.407958984375
# Accuracy of train set: tensor(0.8866, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 55 loss = 70.57177734375
# Accuracy of train set: tensor(0.8848, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 56 loss = 74.24796295166016
# Accuracy of train set: tensor(0.8827, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 57 loss = 69.36946868896484
# Accuracy of train set: tensor(0.8827, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 58 loss = 71.24079895019531
# Accuracy of train set: tensor(0.8845, device='cuda:0')
# Epoch    59: reducing learning rate of group 0 to 2.0000e-06.
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 59 loss = 72.01660919189453
# Accuracy of train set: tensor(0.8807, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 60 loss = 71.54136657714844
# Accuracy of train set: tensor(0.8785, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 61 loss = 69.54386138916016
# Accuracy of train set: tensor(0.8886, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 62 loss = 75.04619598388672
# Accuracy of train set: tensor(0.8779, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 63 loss = 74.10603332519531
# Accuracy of train set: tensor(0.8767, device='cuda:0')
# Epoch    64: reducing learning rate of group 0 to 2.0000e-07.
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 64 loss = 70.3805923461914
# Accuracy of train set: tensor(0.8824, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 65 loss = 71.11854553222656
# Accuracy of train set: tensor(0.8818, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 66 loss = 71.2901382446289
# Accuracy of train set: tensor(0.8854, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 67 loss = 69.47303009033203
# Accuracy of train set: tensor(0.8889, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 68 loss = 69.04813385009766
# Accuracy of train set: tensor(0.8794, device='cuda:0')
# Epoch    69: reducing learning rate of group 0 to 2.0000e-08.
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 69 loss = 72.28031921386719
# Accuracy of train set: tensor(0.8830, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 70 loss = 69.80768585205078
# Accuracy of train set: tensor(0.8857, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 71 loss = 74.5761489868164
# Accuracy of train set: tensor(0.8710, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 72 loss = 67.602294921875
# Accuracy of train set: tensor(0.8863, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 73 loss = 69.1192626953125
# Accuracy of train set: tensor(0.8836, device='cuda:0')
# Epoch    74: reducing learning rate of group 0 to 2.0000e-09.
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 74 loss = 72.41366577148438
# Accuracy of train set: tensor(0.8788, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 75 loss = 68.25958251953125
# Accuracy of train set: tensor(0.8788, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 76 loss = 72.13707733154297
# Accuracy of train set: tensor(0.8808, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 77 loss = 71.92049407958984
# Accuracy of train set: tensor(0.8780, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 78 loss = 72.81324768066406
# Accuracy of train set: tensor(0.8800, device='cuda:0')
# Epoch    79: reducing learning rate of group 0 to 2.0000e-10.
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 79 loss = 70.5008544921875
# Accuracy of train set: tensor(0.8881, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 80 loss = 68.4277114868164
# Accuracy of train set: tensor(0.8878, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 81 loss = 69.23780822753906
# Accuracy of train set: tensor(0.8848, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 82 loss = 70.29039764404297
# Accuracy of train set: tensor(0.8839, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 83 loss = 71.39877319335938
# Accuracy of train set: tensor(0.8783, device='cuda:0')
# Epoch    84: reducing learning rate of group 0 to 2.0000e-11.
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 84 loss = 70.97034454345703
# Accuracy of train set: tensor(0.8762, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 85 loss = 67.58355712890625
# Accuracy of train set: tensor(0.8883, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 86 loss = 72.22452545166016
# Accuracy of train set: tensor(0.8786, device='cuda:0')
# Accuracy of validation set : tensor(0.9716, device='cuda:0')
# Iteration no: 87 loss = 71.10828399658203
# Accuracy of train set: tensor(0.8854, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 88 loss = 66.96228790283203
# Accuracy of train set: tensor(0.8887, device='cuda:0')
# Epoch    89: reducing learning rate of group 0 to 2.0000e-12.
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 89 loss = 73.02781677246094
# Accuracy of train set: tensor(0.8794, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 90 loss = 69.87281799316406
# Accuracy of train set: tensor(0.8902, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 91 loss = 68.08988189697266
# Accuracy of train set: tensor(0.8860, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 92 loss = 73.43365478515625
# Accuracy of train set: tensor(0.8830, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 93 loss = 71.46515655517578
# Accuracy of train set: tensor(0.8807, device='cuda:0')
# Epoch    94: reducing learning rate of group 0 to 2.0000e-13.
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 94 loss = 74.62179565429688
# Accuracy of train set: tensor(0.8803, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 95 loss = 70.86555480957031
# Accuracy of train set: tensor(0.8848, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 96 loss = 69.85102081298828
# Accuracy of train set: tensor(0.8845, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 97 loss = 72.59516143798828
# Accuracy of train set: tensor(0.8794, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 98 loss = 70.32308959960938
# Accuracy of train set: tensor(0.8824, device='cuda:0')
# Epoch    99: reducing learning rate of group 0 to 2.0000e-14.
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 99 loss = 71.73445129394531
# Accuracy of train set: tensor(0.8830, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 100 loss = 70.99561309814453
# Accuracy of train set: tensor(0.8827, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 101 loss = 76.44178771972656
# Accuracy of train set: tensor(0.8773, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 102 loss = 65.51543426513672
# Accuracy of train set: tensor(0.8874, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 103 loss = 75.98237609863281
# Accuracy of train set: tensor(0.8728, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 104 loss = 72.23786163330078
# Accuracy of train set: tensor(0.8815, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 105 loss = 74.39230346679688
# Accuracy of train set: tensor(0.8782, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 106 loss = 68.1903305053711
# Accuracy of train set: tensor(0.8881, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 107 loss = 68.80928039550781
# Accuracy of train set: tensor(0.8863, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 108 loss = 65.72634887695312
# Accuracy of train set: tensor(0.8907, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 109 loss = 72.16594696044922
# Accuracy of train set: tensor(0.8848, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 110 loss = 65.67650604248047
# Accuracy of train set: tensor(0.8937, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 111 loss = 73.5790023803711
# Accuracy of train set: tensor(0.8768, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 112 loss = 78.20287322998047
# Accuracy of train set: tensor(0.8756, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 113 loss = 71.84310913085938
# Accuracy of train set: tensor(0.8806, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 114 loss = 64.54039764404297
# Accuracy of train set: tensor(0.8919, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 115 loss = 74.84629821777344
# Accuracy of train set: tensor(0.8702, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 116 loss = 71.01607513427734
# Accuracy of train set: tensor(0.8794, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 117 loss = 73.36500549316406
# Accuracy of train set: tensor(0.8818, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 118 loss = 70.34046936035156
# Accuracy of train set: tensor(0.8812, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 119 loss = 69.68572235107422
# Accuracy of train set: tensor(0.8839, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')

# %%
torch.save(model, 'drive/My Drive/Colab Notebooks/ITSP/gest_full_googlenet.pth')
