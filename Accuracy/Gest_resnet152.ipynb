# %%
import sys
import os
import torch
import cv2 as cv
import numpy as np
import torchvision
from torch import nn, optim
import torch.nn.functional as F
import torch.utils.data
import torchvision.datasets as dset
import torchvision.utils as vutils
from torch.utils.data import DataLoader
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import random
from torch.utils.data.sampler import SubsetRandomSampler
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Using GPU
print(sys.version)
device = 'cuda'
#Checking for GPU
print(torch.version.cuda)
print(torch.cuda.device_count())
print(torch.cuda.is_available())
# Out:
# 3.6.9 (default, Apr 18 2020, 01:56:04)
# [GCC 8.4.0]
# 10.1
# 1
# True

# %%
lookup = dict()
reverselookup = dict()

count = 0

for j in os.listdir('drive/My Drive/Colab Notebooks/ITSP/mydata/'):
    if not j.startswith('.'):
        lookup[j] = count
        reverselookup[count] = j
        count += 1
        
print(lookup)
print(reverselookup)
# Out:
# {'3': 0, '6': 1, '4': 2, '2': 3, '1': 4, '7': 5, '5': 6, '8': 7, '0': 8, '9': 9}
# {0: '3', 1: '6', 2: '4', 3: '2', 4: '1', 5: '7', 6: '5', 7: '8', 8: '0', 9: '9'}

# %%
x_data = []
y_data = []
datacount = 0
image_size = 256

dataset = dset.ImageFolder(root = 'drive/My Drive/Colab Notebooks/ITSP/mydata', 
                transform = 
                transforms.Compose([
                transforms.Resize(image_size),
                transforms.RandomResizedCrop(size=256, scale=(0.95, 1.0)),
                transforms.RandomRotation(degrees=10),
                transforms.ColorJitter(),
                transforms.RandomHorizontalFlip(0.3),
                transforms.Resize(size=224),  # Image net standards
                transforms.ToTensor(),
                transforms.Normalize([0.485, 0.456, 0.406],
                                     [0.229, 0.224, 0.225])  # Imagenet standards
                #transforms.ToTensor(), 
                #transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                ]))

print(dataset)

batch = 16
random_seed = random.randint(1, 100)

dataset_size = len(dataset)
split = int(0.05*dataset_size)
print('Size of dataset is: ', dataset_size)
print('Split value: ', split)
indices = list(range(dataset_size))

np.random.seed(random_seed)
np.random.shuffle(indices)

train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch, sampler=train_sampler,
                                            num_workers = 2)
valid_loader = torch.utils.data.DataLoader(dataset, batch_size=batch, sampler=valid_sampler,
                                            num_workers = 2)

print(len(train_loader))
print(len(valid_loader))


#for image, label in train_loader:
    #print(label)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 3535
#     Root location: drive/My Drive/Colab Notebooks/ITSP/mydata
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=PIL.Image.BILINEAR)
#                RandomResizedCrop(size=(256, 256), scale=(0.95, 1.0), ratio=(0.75, 1.3333), interpolation=PIL.Image.BILINEAR)
#                RandomRotation(degrees=(-10, 10), resample=False, expand=False)
#                ColorJitter(brightness=None, contrast=None, saturation=None, hue=None)
#                RandomHorizontalFlip(p=0.3)
#                Resize(size=224, interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# Size of dataset is:  3535
# Split value:  176
# 210
# 11

# %%
# Iterate through the dataloader once
trainiter = iter(train_loader)
features, labels = next(trainiter)
features.shape, labels.shape
# Out:
# (torch.Size([16, 3, 224, 224]), torch.Size([16]))

# %%
def get_image_shape():
    img = cv.imread('drive/My Drive/Colab Notebooks/ITSP/mydata/1/1.jpg', 0)
    return img.shape


img_shape = get_image_shape()
print('Image shape: ', img_shape)
root = 'drive/My Drive/Colab Notebooks/ITSP/mydata'
gesture_data = os.listdir(root)
num_g = len(gesture_data)
print('Number of gestures: ', num_g)
num_rows = int(num_g/4)

if(num_g%4):
   num_rows+=1

print('Number of rows: ', num_rows)

begin = 0
final_img = None

for i in range(num_rows):
    row_img = None
    for j in range(begin, begin+4):
        if (j>= num_g):
            img = np.zeros(img_shape, dtype = np.uint8)
            #print('Image index: ', j, 'false')
            
        else:         
            imgpath = root + '/' + reverselookup[j] + '/' + str(random.randint(1, 200)) + '.jpg'
            img = cv.imread(imgpath, 0)
            #if not np.any(img == None):
                #print('Image index: ', j, 'true')
            
        if np.any(row_img == None):
            row_img = img
        else:
            row_img = np.hstack((row_img, img))
            
    begin += 4
    if np.any(final_img == None):
            final_img = row_img
    else:
        final_img = np.vstack((final_img, row_img))  
                        
plt.imshow(final_img, cmap='gray')
#cv.waitKey(0)
#cv.destroyAllWindows()
# Out:
# Image shape:  (256, 256)
# Number of gestures:  10
# Number of rows:  3

# %%
gestures = []
titles = []

for i in range(num_g):
    imgpath = root + '/' + reverselookup[i] + '/' + str(random.randint(1, 200)) + '.jpg'
    img = cv.imread(imgpath, 0)
    gestures.append(img)
    titles.append(reverselookup[i])
    
for i in range(num_g):
    plt.subplot(3, 4, i+1)
    plt.imshow(gestures[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

# %%
from torchvision import models
model = models.resnet152(pretrained=True)
for param in model.parameters():
    param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /root/.cache/torch/checkpoints/resnet152-b121ed2d.pth
# HBox(children=(FloatProgress(value=0.0, max=241530880.0), HTML(value='')))

# %%
torch.save(model, 'drive/My Drive/Colab Notebooks/ITSP/weights2.pth')
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
n_classes = 10

model.fc = nn.Sequential(
                      nn.Linear(2048, 512), 
                      nn.ReLU(), 
                      nn.Linear(512, 256), 
                      nn.ReLU(),
                      nn.Dropout(0.1), 
                      nn.Linear(256, n_classes),                   
                      nn.LogSoftmax(dim=1))

print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Dropout(p=0.1, inplace=False)
#     (5): Linear(in_features=256, out_features=10, bias=True)
#     (6): LogSoftmax()
#   )
# )

# %%
total_params = sum(p.numel() for p in model.parameters())

print(f'{total_params:,} total parameters')

total_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'{total_trainable:,} trainable parameters.')
# Out:
# 59,326,794 total parameters
# 1,182,986 trainable parameters.

# %%
# Move to gpu
model = model.to('cuda')
# Distribute across 2 gpus
model = nn.DataParallel(model)

loss_func = F.cross_entropy
optimizer = optim.Adam(model.parameters(), betas=(0.5, 0.99), lr = 0.002)

# %%
def accuracy(out, yb):
    pred = torch.argmax(out, keepdim= False, dim=1)
    return (pred == yb).float().mean()

# %%
def fit(model, epochs, train_loader, valid_loader, opt):
    losses = []
    
    for epoch in range(epochs):
        train_loss =0
        train_acc =0
        model.train()
        for xb, yb in train_loader:
            xb =xb.to(device)
            yb = yb.to(device)
            pred = model(xb.float())
            pred.to(device)
            train_acc += accuracy(pred, yb)
            loss = loss_func(pred, yb)
            train_loss += loss
            #back propogation
            loss.backward()
            opt.step()
            opt.zero_grad()      

        losses.append(train_loss)
        print("Iteration no: "+ str(epoch), "loss = "+str(losses[epoch].item()))
        print("Accuracy of train set:", train_acc/len(train_loader))
        lr_scheduler.step(train_loss/len(train_loader))
        
        
        model.eval()    
        with torch.no_grad():
            valid_acc=0
            loss_valid = 0
            for xb_valid, yb_valid in valid_loader:
                xb_valid = xb_valid.to(device)
                yb_valid = yb_valid.to(device)
                pred_valid = model(xb_valid.float())
                pred_valid.to(device)
                valid_acc += accuracy(pred_valid, yb_valid)
                loss_valid += loss_func(pred_valid, yb_valid)
            print("Accuracy of validation set :", valid_acc/len(valid_loader))

    plt.plot(losses)
    plt.ylabel("loss")
    plt.xlabel("iterations")
    plt.show()

# %%
lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=4, verbose=True, eps = 10e-14)

fit(model, 180, train_loader, valid_loader, optimizer)
# Out:
# Iteration no: 0 loss = 281.234130859375
# Accuracy of train set: tensor(0.5032, device='cuda:0')
# Accuracy of validation set : tensor(0.7386, device='cuda:0')
# Iteration no: 1 loss = 163.3691864013672
# Accuracy of train set: tensor(0.7193, device='cuda:0')
# Accuracy of validation set : tensor(0.7898, device='cuda:0')
# Iteration no: 2 loss = 130.09725952148438
# Accuracy of train set: tensor(0.7738, device='cuda:0')
# Accuracy of validation set : tensor(0.7614, device='cuda:0')
# Iteration no: 3 loss = 116.08122253417969
# Accuracy of train set: tensor(0.8049, device='cuda:0')
# Accuracy of validation set : tensor(0.8864, device='cuda:0')
# Iteration no: 4 loss = 109.63497924804688
# Accuracy of train set: tensor(0.8122, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 5 loss = 107.01092529296875
# Accuracy of train set: tensor(0.8262, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 6 loss = 103.92416381835938
# Accuracy of train set: tensor(0.8247, device='cuda:0')
# Accuracy of validation set : tensor(0.8750, device='cuda:0')
# Iteration no: 7 loss = 98.6786880493164
# Accuracy of train set: tensor(0.8371, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 8 loss = 97.00098419189453
# Accuracy of train set: tensor(0.8396, device='cuda:0')
# Accuracy of validation set : tensor(0.8466, device='cuda:0')
# Iteration no: 9 loss = 96.088623046875
# Accuracy of train set: tensor(0.8443, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 10 loss = 94.27776336669922
# Accuracy of train set: tensor(0.8497, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 11 loss = 84.12840270996094
# Accuracy of train set: tensor(0.8661, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 12 loss = 91.37947082519531
# Accuracy of train set: tensor(0.8461, device='cuda:0')
# Accuracy of validation set : tensor(0.8636, device='cuda:0')
# Iteration no: 13 loss = 82.43265533447266
# Accuracy of train set: tensor(0.8607, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 14 loss = 83.77826690673828
# Accuracy of train set: tensor(0.8687, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 15 loss = 93.0312271118164
# Accuracy of train set: tensor(0.8505, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 16 loss = 76.83597564697266
# Accuracy of train set: tensor(0.8717, device='cuda:0')
# Accuracy of validation set : tensor(0.8750, device='cuda:0')
# Iteration no: 17 loss = 76.83026123046875
# Accuracy of train set: tensor(0.8726, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 18 loss = 83.9400405883789
# Accuracy of train set: tensor(0.8681, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 19 loss = 81.20587921142578
# Accuracy of train set: tensor(0.8743, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 20 loss = 79.96048736572266
# Accuracy of train set: tensor(0.8723, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 21 loss = 77.92422485351562
# Accuracy of train set: tensor(0.8705, device='cuda:0')
# Epoch    22: reducing learning rate of group 0 to 2.0000e-04.
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 22 loss = 56.36664962768555
# Accuracy of train set: tensor(0.9107, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 23 loss = 46.6964225769043
# Accuracy of train set: tensor(0.9232, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 24 loss = 57.55405807495117
# Accuracy of train set: tensor(0.9015, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 25 loss = 48.197750091552734
# Accuracy of train set: tensor(0.9185, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 26 loss = 50.759010314941406
# Accuracy of train set: tensor(0.9193, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 27 loss = 51.29317092895508
# Accuracy of train set: tensor(0.9119, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 28 loss = 46.07194900512695
# Accuracy of train set: tensor(0.9303, device='cuda:0')
# Accuracy of validation set : tensor(0.9716, device='cuda:0')
# Iteration no: 29 loss = 50.52039337158203
# Accuracy of train set: tensor(0.9223, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 30 loss = 49.069026947021484
# Accuracy of train set: tensor(0.9235, device='cuda:0')
# Accuracy of validation set : tensor(0.9830, device='cuda:0')
# Iteration no: 31 loss = 51.57915115356445
# Accuracy of train set: tensor(0.9172, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 32 loss = 50.3155517578125
# Accuracy of train set: tensor(0.9166, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 33 loss = 46.58544158935547
# Accuracy of train set: tensor(0.9247, device='cuda:0')
# Epoch    34: reducing learning rate of group 0 to 2.0000e-05.
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 34 loss = 44.08390808105469
# Accuracy of train set: tensor(0.9285, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 35 loss = 48.24116134643555
# Accuracy of train set: tensor(0.9205, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 36 loss = 45.43264389038086
# Accuracy of train set: tensor(0.9187, device='cuda:0')
# Accuracy of validation set : tensor(0.9830, device='cuda:0')
# Iteration no: 37 loss = 43.0546989440918
# Accuracy of train set: tensor(0.9301, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 38 loss = 41.349308013916016
# Accuracy of train set: tensor(0.9357, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 39 loss = 46.437530517578125
# Accuracy of train set: tensor(0.9202, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 40 loss = 45.09638977050781
# Accuracy of train set: tensor(0.9286, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 41 loss = 45.436824798583984
# Accuracy of train set: tensor(0.9234, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 42 loss = 44.62432098388672
# Accuracy of train set: tensor(0.9283, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 43 loss = 45.316158294677734
# Accuracy of train set: tensor(0.9303, device='cuda:0')
# Epoch    44: reducing learning rate of group 0 to 2.0000e-06.
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 44 loss = 49.81441116333008
# Accuracy of train set: tensor(0.9196, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 45 loss = 43.55609893798828
# Accuracy of train set: tensor(0.9258, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 46 loss = 45.40599822998047
# Accuracy of train set: tensor(0.9274, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 47 loss = 45.92914581298828
# Accuracy of train set: tensor(0.9185, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 48 loss = 50.24277877807617
# Accuracy of train set: tensor(0.9217, device='cuda:0')
# Epoch    49: reducing learning rate of group 0 to 2.0000e-07.
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 49 loss = 44.2900390625
# Accuracy of train set: tensor(0.9214, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 50 loss = 50.10429763793945
# Accuracy of train set: tensor(0.9205, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 51 loss = 43.53843688964844
# Accuracy of train set: tensor(0.9244, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 52 loss = 43.775535583496094
# Accuracy of train set: tensor(0.9271, device='cuda:0')
# Accuracy of validation set : tensor(0.9886, device='cuda:0')
# Iteration no: 53 loss = 48.13914489746094
# Accuracy of train set: tensor(0.9202, device='cuda:0')
# Epoch    54: reducing learning rate of group 0 to 2.0000e-08.
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 54 loss = 45.29734420776367
# Accuracy of train set: tensor(0.9262, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 55 loss = 44.03572082519531
# Accuracy of train set: tensor(0.9274, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 56 loss = 44.356597900390625
# Accuracy of train set: tensor(0.9253, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 57 loss = 49.391422271728516
# Accuracy of train set: tensor(0.9250, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 58 loss = 44.323604583740234
# Accuracy of train set: tensor(0.9259, device='cuda:0')
# Epoch    59: reducing learning rate of group 0 to 2.0000e-09.
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 59 loss = 47.816162109375
# Accuracy of train set: tensor(0.9232, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 60 loss = 42.8603630065918
# Accuracy of train set: tensor(0.9274, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 61 loss = 40.75886154174805
# Accuracy of train set: tensor(0.9368, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 62 loss = 42.94968032836914
# Accuracy of train set: tensor(0.9253, device='cuda:0')
# Accuracy of validation set : tensor(0.9773, device='cuda:0')
# Iteration no: 63 loss = 46.629737854003906
# Accuracy of train set: tensor(0.9172, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 64 loss = 43.37502670288086
# Accuracy of train set: tensor(0.9271, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 65 loss = 45.94572067260742
# Accuracy of train set: tensor(0.9259, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 66 loss = 41.28423309326172
# Accuracy of train set: tensor(0.9286, device='cuda:0')
# Epoch    67: reducing learning rate of group 0 to 2.0000e-10.
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 67 loss = 45.85502624511719
# Accuracy of train set: tensor(0.9273, device='cuda:0')
# Accuracy of validation set : tensor(0.9716, device='cuda:0')
# Iteration no: 68 loss = 43.73263168334961
# Accuracy of train set: tensor(0.9291, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 69 loss = 44.149017333984375
# Accuracy of train set: tensor(0.9315, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 70 loss = 48.47418975830078
# Accuracy of train set: tensor(0.9161, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 71 loss = 48.736961364746094
# Accuracy of train set: tensor(0.9188, device='cuda:0')
# Epoch    72: reducing learning rate of group 0 to 2.0000e-11.
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 72 loss = 44.299007415771484
# Accuracy of train set: tensor(0.9286, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 73 loss = 46.100685119628906
# Accuracy of train set: tensor(0.9250, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 74 loss = 46.92244338989258
# Accuracy of train set: tensor(0.9244, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 75 loss = 46.87510681152344
# Accuracy of train set: tensor(0.9223, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 76 loss = 44.80789566040039
# Accuracy of train set: tensor(0.9232, device='cuda:0')
# Epoch    77: reducing learning rate of group 0 to 2.0000e-12.
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 77 loss = 44.60688018798828
# Accuracy of train set: tensor(0.9256, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 78 loss = 46.05712890625
# Accuracy of train set: tensor(0.9223, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 79 loss = 47.528175354003906
# Accuracy of train set: tensor(0.9226, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 80 loss = 46.65834426879883
# Accuracy of train set: tensor(0.9253, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 81 loss = 45.214839935302734
# Accuracy of train set: tensor(0.9268, device='cuda:0')
# Epoch    82: reducing learning rate of group 0 to 2.0000e-13.
# Accuracy of validation set : tensor(0.9773, device='cuda:0')
# Iteration no: 82 loss = 41.347869873046875
# Accuracy of train set: tensor(0.9297, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 83 loss = 43.090091705322266
# Accuracy of train set: tensor(0.9262, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 84 loss = 41.80842590332031
# Accuracy of train set: tensor(0.9276, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 85 loss = 44.690494537353516
# Accuracy of train set: tensor(0.9294, device='cuda:0')
# Accuracy of validation set : tensor(0.9773, device='cuda:0')
# Iteration no: 86 loss = 41.450523376464844
# Accuracy of train set: tensor(0.9294, device='cuda:0')
# Epoch    87: reducing learning rate of group 0 to 2.0000e-14.
# Accuracy of validation set : tensor(0.9773, device='cuda:0')
# Iteration no: 87 loss = 45.015380859375
# Accuracy of train set: tensor(0.9247, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 88 loss = 45.43613052368164
# Accuracy of train set: tensor(0.9297, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 89 loss = 45.14693832397461
# Accuracy of train set: tensor(0.9282, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 90 loss = 45.24973678588867
# Accuracy of train set: tensor(0.9273, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 91 loss = 45.61636734008789
# Accuracy of train set: tensor(0.9247, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 92 loss = 46.563446044921875
# Accuracy of train set: tensor(0.9220, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 93 loss = 42.564727783203125
# Accuracy of train set: tensor(0.9271, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 94 loss = 46.31636047363281
# Accuracy of train set: tensor(0.9280, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 95 loss = 44.395904541015625
# Accuracy of train set: tensor(0.9280, device='cuda:0')
# Accuracy of validation set : tensor(0.9830, device='cuda:0')
# Iteration no: 96 loss = 45.1361198425293
# Accuracy of train set: tensor(0.9253, device='cuda:0')
# Accuracy of validation set : tensor(0.9830, device='cuda:0')
# Iteration no: 97 loss = 41.64008331298828
# Accuracy of train set: tensor(0.9283, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 98 loss = 44.36805725097656
# Accuracy of train set: tensor(0.9274, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 99 loss = 43.15879440307617
# Accuracy of train set: tensor(0.9298, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 100 loss = 43.86463928222656
# Accuracy of train set: tensor(0.9273, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 101 loss = 44.27732467651367
# Accuracy of train set: tensor(0.9270, device='cuda:0')
# Accuracy of validation set : tensor(0.9716, device='cuda:0')
# Iteration no: 102 loss = 43.538578033447266
# Accuracy of train set: tensor(0.9291, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 103 loss = 46.67669677734375
# Accuracy of train set: tensor(0.9280, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 104 loss = 45.05281066894531
# Accuracy of train set: tensor(0.9277, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 105 loss = 46.91023635864258
# Accuracy of train set: tensor(0.9247, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 106 loss = 42.48260498046875
# Accuracy of train set: tensor(0.9256, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 107 loss = 43.84379577636719
# Accuracy of train set: tensor(0.9295, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 108 loss = 47.009639739990234
# Accuracy of train set: tensor(0.9211, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 109 loss = 44.79628372192383
# Accuracy of train set: tensor(0.9271, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 110 loss = 43.85260772705078
# Accuracy of train set: tensor(0.9295, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 111 loss = 40.861473083496094
# Accuracy of train set: tensor(0.9286, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 112 loss = 44.35716247558594
# Accuracy of train set: tensor(0.9262, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 113 loss = 46.94038391113281
# Accuracy of train set: tensor(0.9262, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 114 loss = 47.6733512878418
# Accuracy of train set: tensor(0.9229, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 115 loss = 48.39577102661133
# Accuracy of train set: tensor(0.9199, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 116 loss = 44.73625946044922
# Accuracy of train set: tensor(0.9247, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 117 loss = 46.13900375366211
# Accuracy of train set: tensor(0.9238, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 118 loss = 42.224849700927734
# Accuracy of train set: tensor(0.9277, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 119 loss = 47.24241638183594
# Accuracy of train set: tensor(0.9252, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 120 loss = 43.956363677978516
# Accuracy of train set: tensor(0.9259, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 121 loss = 42.14442825317383
# Accuracy of train set: tensor(0.9274, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 122 loss = 47.8211555480957
# Accuracy of train set: tensor(0.9193, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 123 loss = 44.85701370239258
# Accuracy of train set: tensor(0.9262, device='cuda:0')
# Accuracy of validation set : tensor(0.9716, device='cuda:0')
# Iteration no: 124 loss = 43.894168853759766
# Accuracy of train set: tensor(0.9247, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 125 loss = 45.45107650756836
# Accuracy of train set: tensor(0.9253, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 126 loss = 42.272064208984375
# Accuracy of train set: tensor(0.9285, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 127 loss = 44.433284759521484
# Accuracy of train set: tensor(0.9241, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 128 loss = 44.975399017333984
# Accuracy of train set: tensor(0.9217, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 129 loss = 41.47998809814453
# Accuracy of train set: tensor(0.9342, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 130 loss = 45.383544921875
# Accuracy of train set: tensor(0.9283, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 131 loss = 43.26753234863281
# Accuracy of train set: tensor(0.9303, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 132 loss = 41.26064682006836
# Accuracy of train set: tensor(0.9339, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 133 loss = 47.6488151550293
# Accuracy of train set: tensor(0.9265, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 134 loss = 46.25531005859375
# Accuracy of train set: tensor(0.9211, device='cuda:0')
# Accuracy of validation set : tensor(0.9716, device='cuda:0')
# Iteration no: 135 loss = 42.72321701049805
# Accuracy of train set: tensor(0.9270, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 136 loss = 42.803043365478516
# Accuracy of train set: tensor(0.9271, device='cuda:0')
# Accuracy of validation set : tensor(0.9716, device='cuda:0')
# Iteration no: 137 loss = 42.705169677734375
# Accuracy of train set: tensor(0.9300, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 138 loss = 42.41373825073242
# Accuracy of train set: tensor(0.9310, device='cuda:0')
# Accuracy of validation set : tensor(0.9773, device='cuda:0')
# Iteration no: 139 loss = 46.98194885253906
# Accuracy of train set: tensor(0.9262, device='cuda:0')
# Accuracy of validation set : tensor(0.9716, device='cuda:0')
# Iteration no: 140 loss = 46.85516357421875
# Accuracy of train set: tensor(0.9223, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 141 loss = 43.79214096069336
# Accuracy of train set: tensor(0.9283, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 142 loss = 44.48050308227539
# Accuracy of train set: tensor(0.9253, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 143 loss = 48.65915298461914
# Accuracy of train set: tensor(0.9220, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 144 loss = 40.402976989746094
# Accuracy of train set: tensor(0.9315, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 145 loss = 45.5867805480957
# Accuracy of train set: tensor(0.9291, device='cuda:0')
# Accuracy of validation set : tensor(0.9716, device='cuda:0')
# Iteration no: 146 loss = 42.56363296508789
# Accuracy of train set: tensor(0.9304, device='cuda:0')
# Accuracy of validation set : tensor(0.9716, device='cuda:0')
# Iteration no: 147 loss = 41.79058074951172
# Accuracy of train set: tensor(0.9313, device='cuda:0')
# Accuracy of validation set : tensor(0.9773, device='cuda:0')
# Iteration no: 148 loss = 42.95830535888672
# Accuracy of train set: tensor(0.9280, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 149 loss = 44.527259826660156
# Accuracy of train set: tensor(0.9244, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 150 loss = 41.747066497802734
# Accuracy of train set: tensor(0.9262, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 151 loss = 44.67803955078125
# Accuracy of train set: tensor(0.9256, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 152 loss = 41.971954345703125
# Accuracy of train set: tensor(0.9336, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 153 loss = 49.91010284423828
# Accuracy of train set: tensor(0.9211, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 154 loss = 45.40468215942383
# Accuracy of train set: tensor(0.9274, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 155 loss = 43.393856048583984
# Accuracy of train set: tensor(0.9295, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 156 loss = 41.633079528808594
# Accuracy of train set: tensor(0.9312, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 157 loss = 45.953433990478516
# Accuracy of train set: tensor(0.9232, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 158 loss = 47.71980667114258
# Accuracy of train set: tensor(0.9244, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 159 loss = 43.65019989013672
# Accuracy of train set: tensor(0.9277, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 160 loss = 44.472415924072266
# Accuracy of train set: tensor(0.9333, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 161 loss = 48.23405456542969
# Accuracy of train set: tensor(0.9193, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 162 loss = 45.65713119506836
# Accuracy of train set: tensor(0.9247, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 163 loss = 41.98192596435547
# Accuracy of train set: tensor(0.9297, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 164 loss = 42.74110412597656
# Accuracy of train set: tensor(0.9285, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 165 loss = 48.00571060180664
# Accuracy of train set: tensor(0.9202, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 166 loss = 45.019107818603516
# Accuracy of train set: tensor(0.9229, device='cuda:0')
# Accuracy of validation set : tensor(0.9830, device='cuda:0')
# Iteration no: 167 loss = 42.777503967285156
# Accuracy of train set: tensor(0.9291, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 168 loss = 40.31339645385742
# Accuracy of train set: tensor(0.9310, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 169 loss = 47.20591735839844
# Accuracy of train set: tensor(0.9140, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 170 loss = 42.74176788330078
# Accuracy of train set: tensor(0.9238, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 171 loss = 44.2448616027832
# Accuracy of train set: tensor(0.9238, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 172 loss = 45.52466583251953
# Accuracy of train set: tensor(0.9229, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 173 loss = 41.9104118347168
# Accuracy of train set: tensor(0.9300, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 174 loss = 46.680973052978516
# Accuracy of train set: tensor(0.9226, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 175 loss = 45.14968490600586
# Accuracy of train set: tensor(0.9283, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 176 loss = 39.02947998046875
# Accuracy of train set: tensor(0.9372, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 177 loss = 47.64360046386719
# Accuracy of train set: tensor(0.9199, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 178 loss = 42.399070739746094
# Accuracy of train set: tensor(0.9253, device='cuda:0')
# Accuracy of validation set : tensor(0.9659, device='cuda:0')
# Iteration no: 179 loss = 44.88224411010742
# Accuracy of train set: tensor(0.9279, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')

# %%
torch.save(model, 'drive/My Drive/Colab Notebooks/ITSP/gest_full8.pth')
