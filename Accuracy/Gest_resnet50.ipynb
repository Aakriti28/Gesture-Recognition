# %%
import sys
import os
import torch
import cv2 as cv
import numpy as np
import torchvision
from torch import nn, optim
import torch.nn.functional as F
import torch.utils.data
import torchvision.datasets as dset
import torchvision.utils as vutils
from torch.utils.data import DataLoader
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import random
from torch.utils.data.sampler import SubsetRandomSampler
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Using GPU
print(sys.version)
device = 'cuda'
#Checking for GPU
print(torch.version.cuda)
print(torch.cuda.device_count())
print(torch.cuda.is_available())
# Out:
# 3.6.9 (default, Apr 18 2020, 01:56:04)
# [GCC 8.4.0]
# 10.1
# 1
# True

# %%
lookup = dict()
reverselookup = dict()

count = 0

for j in os.listdir('drive/My Drive/Colab Notebooks/ITSP/mydata/'):
    if not j.startswith('.'):
        lookup[j] = count
        reverselookup[count] = j
        count += 1
        
print(lookup)
print(reverselookup)
# Out:
# {'3': 0, '6': 1, '4': 2, '2': 3, '1': 4, '7': 5, '5': 6, '8': 7, '0': 8, '9': 9}
# {0: '3', 1: '6', 2: '4', 3: '2', 4: '1', 5: '7', 6: '5', 7: '8', 8: '0', 9: '9'}

# %%
x_data = []
y_data = []
datacount = 0
image_size = 256

dataset = dset.ImageFolder(root = 'drive/My Drive/Colab Notebooks/ITSP/mydata', 
                transform = 
                transforms.Compose([
                transforms.Resize(image_size),
                transforms.RandomResizedCrop(size=256, scale=(0.95, 1.0)),
                transforms.RandomRotation(degrees=10),
                transforms.ColorJitter(),
                transforms.RandomHorizontalFlip(0.3),
                transforms.Resize(size=224),  # Image net standards
                transforms.ToTensor(),
                transforms.Normalize([0.485, 0.456, 0.406],
                                     [0.229, 0.224, 0.225])  # Imagenet standards
                #transforms.ToTensor(), 
                #transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                ]))

print(dataset)

batch = 16
random_seed = random.randint(1, 100)

dataset_size = len(dataset)
split = int(0.05*dataset_size)
print('Size of dataset is: ', dataset_size)
print('Split value: ', split)
indices = list(range(dataset_size))

np.random.seed(random_seed)
np.random.shuffle(indices)

train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch, sampler=train_sampler,
                                            num_workers = 2)
valid_loader = torch.utils.data.DataLoader(dataset, batch_size=batch, sampler=valid_sampler,
                                            num_workers = 2)

print(len(train_loader))
print(len(valid_loader))


#for image, label in train_loader:
    #print(label)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 3535
#     Root location: drive/My Drive/Colab Notebooks/ITSP/mydata
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=PIL.Image.BILINEAR)
#                RandomResizedCrop(size=(256, 256), scale=(0.95, 1.0), ratio=(0.75, 1.3333), interpolation=PIL.Image.BILINEAR)
#                RandomRotation(degrees=(-10, 10), resample=False, expand=False)
#                ColorJitter(brightness=None, contrast=None, saturation=None, hue=None)
#                RandomHorizontalFlip(p=0.3)
#                Resize(size=224, interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# Size of dataset is:  3535
# Split value:  176
# 210
# 11

# %%
# Iterate through the dataloader once
trainiter = iter(train_loader)
features, labels = next(trainiter)
features.shape, labels.shape
# Out:
# (torch.Size([16, 3, 224, 224]), torch.Size([16]))

# %%
def get_image_shape():
    img = cv.imread('drive/My Drive/Colab Notebooks/ITSP/mydata/1/1.jpg', 0)
    return img.shape


img_shape = get_image_shape()
print('Image shape: ', img_shape)
root = 'drive/My Drive/Colab Notebooks/ITSP/mydata'
gesture_data = os.listdir(root)
num_g = len(gesture_data)
print('Number of gestures: ', num_g)
num_rows = int(num_g/4)

if(num_g%4):
   num_rows+=1

print('Number of rows: ', num_rows)

begin = 0
final_img = None

for i in range(num_rows):
    row_img = None
    for j in range(begin, begin+4):
        if (j>= num_g):
            img = np.zeros(img_shape, dtype = np.uint8)
            #print('Image index: ', j, 'false')
            
        else:         
            imgpath = root + '/' + reverselookup[j] + '/' + str(random.randint(1, 200)) + '.jpg'
            img = cv.imread(imgpath, 0)
            #if not np.any(img == None):
                #print('Image index: ', j, 'true')
            
        if np.any(row_img == None):
            row_img = img
        else:
            row_img = np.hstack((row_img, img))
            
    begin += 4
    if np.any(final_img == None):
            final_img = row_img
    else:
        final_img = np.vstack((final_img, row_img))  
                        
plt.imshow(final_img, cmap='gray')
#cv.waitKey(0)
#cv.destroyAllWindows()
# Out:
# Image shape:  (256, 256)
# Number of gestures:  10
# Number of rows:  3

# %%
gestures = []
titles = []

for i in range(num_g):
    imgpath = root + '/' + reverselookup[i] + '/' + str(random.randint(1, 200)) + '.jpg'
    img = cv.imread(imgpath, 0)
    gestures.append(img)
    titles.append(reverselookup[i])
    
for i in range(num_g):
    plt.subplot(3, 4, i+1)
    plt.imshow(gestures[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

# %%
from torchvision import models
model = models.resnet50(pretrained=True)
for param in model.parameters():
    param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
torch.save(model, 'drive/My Drive/Colab Notebooks/ITSP/resnet50.pth')
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
n_classes = 10

model.fc = nn.Sequential(
                      nn.Linear(2048, 256), 
                      nn.ReLU(), 
                      nn.Linear(256, 128), 
                      nn.ReLU(),
                      nn.Dropout(0.2), 
                      nn.Linear(128, n_classes),                   
                      nn.LogSoftmax(dim=1))

print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Dropout(p=0.2, inplace=False)
#     (5): Linear(in_features=128, out_features=10, bias=True)
#     (6): LogSoftmax()
#   )
# )

# %%
total_params = sum(p.numel() for p in model.parameters())

print(f'{total_params:,} total parameters')

total_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'{total_trainable:,} trainable parameters.')
# Out:
# 24,066,762 total parameters
# 558,730 trainable parameters.

# %%
# Move to gpu
model = model.to('cuda')
# Distribute across 2 gpus
model = nn.DataParallel(model)

loss_func = F.cross_entropy
optimizer = optim.Adam(model.parameters(), betas=(0.5, 0.99), lr = 0.002)

# %%
def accuracy(out, yb):
    pred = torch.argmax(out, keepdim= False, dim=1)
    return (pred == yb).float().mean()

# %%
def fit(model, epochs, train_loader, valid_loader, opt):
    losses = []
    
    for epoch in range(epochs):
        train_loss =0
        train_acc =0
        model.train()
        for xb, yb in train_loader:
            xb =xb.to(device)
            yb = yb.to(device)
            pred = model(xb.float())
            pred.to(device)
            train_acc += accuracy(pred, yb)
            loss = loss_func(pred, yb)
            train_loss += loss
            #back propogation
            loss.backward()
            opt.step()
            opt.zero_grad()      

        losses.append(train_loss)
        print("Iteration no: "+ str(epoch), "loss = "+str(losses[epoch].item()))
        print("Accuracy of train set:", train_acc/len(train_loader))
        lr_scheduler.step(train_loss/len(train_loader))
        
        
        model.eval()    
        with torch.no_grad():
            valid_acc=0
            loss_valid = 0
            for xb_valid, yb_valid in valid_loader:
                xb_valid = xb_valid.to(device)
                yb_valid = yb_valid.to(device)
                pred_valid = model(xb_valid.float())
                pred_valid.to(device)
                valid_acc += accuracy(pred_valid, yb_valid)
                loss_valid += loss_func(pred_valid, yb_valid)
            print("Accuracy of validation set :", valid_acc/len(valid_loader))
            #callbacks = [EarlyStopping(monitor='valid_acc', verbose=False, mode='max', patience=10)]

    plt.plot(losses)
    plt.ylabel("loss")
    plt.xlabel("iterations")
    plt.show()

# %%
#model.set_callbacks(callbacks)

lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=4, verbose=True, eps = 10e-14)

# %%
fit(model, 120, train_loader, valid_loader, optimizer)
# Out:
# Iteration no: 0 loss = 340.6302490234375
# Accuracy of train set: tensor(0.3838, device='cuda:0')
# Accuracy of validation set : tensor(0.6648, device='cuda:0')
# Iteration no: 1 loss = 205.4935302734375
# Accuracy of train set: tensor(0.6142, device='cuda:0')
# Accuracy of validation set : tensor(0.7841, device='cuda:0')
# Iteration no: 2 loss = 168.99781799316406
# Accuracy of train set: tensor(0.7061, device='cuda:0')
# Accuracy of validation set : tensor(0.7955, device='cuda:0')
# Iteration no: 3 loss = 151.0259246826172
# Accuracy of train set: tensor(0.7354, device='cuda:0')
# Accuracy of validation set : tensor(0.8295, device='cuda:0')
# Iteration no: 4 loss = 135.45709228515625
# Accuracy of train set: tensor(0.7655, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 5 loss = 125.15611267089844
# Accuracy of train set: tensor(0.7895, device='cuda:0')
# Accuracy of validation set : tensor(0.8693, device='cuda:0')
# Iteration no: 6 loss = 126.20000457763672
# Accuracy of train set: tensor(0.7916, device='cuda:0')
# Accuracy of validation set : tensor(0.7784, device='cuda:0')
# Iteration no: 7 loss = 114.16300964355469
# Accuracy of train set: tensor(0.7985, device='cuda:0')
# Accuracy of validation set : tensor(0.8864, device='cuda:0')
# Iteration no: 8 loss = 107.06360626220703
# Accuracy of train set: tensor(0.8247, device='cuda:0')
# Accuracy of validation set : tensor(0.8352, device='cuda:0')
# Iteration no: 9 loss = 111.1962661743164
# Accuracy of train set: tensor(0.8103, device='cuda:0')
# Accuracy of validation set : tensor(0.8693, device='cuda:0')
# Iteration no: 10 loss = 111.97145080566406
# Accuracy of train set: tensor(0.8220, device='cuda:0')
# Accuracy of validation set : tensor(0.8807, device='cuda:0')
# Iteration no: 11 loss = 109.27755737304688
# Accuracy of train set: tensor(0.8116, device='cuda:0')
# Accuracy of validation set : tensor(0.8807, device='cuda:0')
# Iteration no: 12 loss = 109.3469009399414
# Accuracy of train set: tensor(0.8228, device='cuda:0')
# Accuracy of validation set : tensor(0.8580, device='cuda:0')
# Iteration no: 13 loss = 105.18323516845703
# Accuracy of train set: tensor(0.8306, device='cuda:0')
# Accuracy of validation set : tensor(0.8693, device='cuda:0')
# Iteration no: 14 loss = 100.0007553100586
# Accuracy of train set: tensor(0.8365, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 15 loss = 104.32584381103516
# Accuracy of train set: tensor(0.8259, device='cuda:0')
# Accuracy of validation set : tensor(0.8920, device='cuda:0')
# Iteration no: 16 loss = 100.47372436523438
# Accuracy of train set: tensor(0.8386, device='cuda:0')
# Accuracy of validation set : tensor(0.8864, device='cuda:0')
# Iteration no: 17 loss = 95.38714599609375
# Accuracy of train set: tensor(0.8403, device='cuda:0')
# Accuracy of validation set : tensor(0.8409, device='cuda:0')
# Iteration no: 18 loss = 96.61687469482422
# Accuracy of train set: tensor(0.8413, device='cuda:0')
# Accuracy of validation set : tensor(0.8920, device='cuda:0')
# Iteration no: 19 loss = 101.71407318115234
# Accuracy of train set: tensor(0.8265, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 20 loss = 91.20347595214844
# Accuracy of train set: tensor(0.8505, device='cuda:0')
# Accuracy of validation set : tensor(0.8920, device='cuda:0')
# Iteration no: 21 loss = 97.10009765625
# Accuracy of train set: tensor(0.8425, device='cuda:0')
# Accuracy of validation set : tensor(0.8750, device='cuda:0')
# Iteration no: 22 loss = 90.1202392578125
# Accuracy of train set: tensor(0.8607, device='cuda:0')
# Accuracy of validation set : tensor(0.8523, device='cuda:0')
# Iteration no: 23 loss = 87.92115020751953
# Accuracy of train set: tensor(0.8559, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 24 loss = 93.3320541381836
# Accuracy of train set: tensor(0.8520, device='cuda:0')
# Accuracy of validation set : tensor(0.8580, device='cuda:0')
# Iteration no: 25 loss = 94.54805755615234
# Accuracy of train set: tensor(0.8443, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 26 loss = 87.07882690429688
# Accuracy of train set: tensor(0.8601, device='cuda:0')
# Accuracy of validation set : tensor(0.8693, device='cuda:0')
# Iteration no: 27 loss = 83.98336029052734
# Accuracy of train set: tensor(0.8586, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 28 loss = 91.00914001464844
# Accuracy of train set: tensor(0.8520, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 29 loss = 87.82785034179688
# Accuracy of train set: tensor(0.8589, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 30 loss = 84.35124969482422
# Accuracy of train set: tensor(0.8619, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 31 loss = 85.59715270996094
# Accuracy of train set: tensor(0.8636, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 32 loss = 87.87751770019531
# Accuracy of train set: tensor(0.8574, device='cuda:0')
# Epoch    33: reducing learning rate of group 0 to 2.0000e-04.
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 33 loss = 63.153350830078125
# Accuracy of train set: tensor(0.8964, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 34 loss = 60.99113464355469
# Accuracy of train set: tensor(0.9056, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 35 loss = 61.90498733520508
# Accuracy of train set: tensor(0.8970, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 36 loss = 61.83457946777344
# Accuracy of train set: tensor(0.9011, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 37 loss = 57.034202575683594
# Accuracy of train set: tensor(0.9053, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 38 loss = 59.49580383300781
# Accuracy of train set: tensor(0.9000, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 39 loss = 57.33639907836914
# Accuracy of train set: tensor(0.9101, device='cuda:0')
# Accuracy of validation set : tensor(0.8864, device='cuda:0')
# Iteration no: 40 loss = 60.855224609375
# Accuracy of train set: tensor(0.9017, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 41 loss = 55.030147552490234
# Accuracy of train set: tensor(0.9077, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 42 loss = 57.316776275634766
# Accuracy of train set: tensor(0.9065, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 43 loss = 56.875892639160156
# Accuracy of train set: tensor(0.9107, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 44 loss = 51.80223846435547
# Accuracy of train set: tensor(0.9143, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 45 loss = 56.75695037841797
# Accuracy of train set: tensor(0.9092, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 46 loss = 51.708290100097656
# Accuracy of train set: tensor(0.9158, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 47 loss = 62.74972152709961
# Accuracy of train set: tensor(0.8937, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 48 loss = 58.357601165771484
# Accuracy of train set: tensor(0.9059, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 49 loss = 59.91983413696289
# Accuracy of train set: tensor(0.9038, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 50 loss = 56.67644500732422
# Accuracy of train set: tensor(0.9113, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 51 loss = 56.89834213256836
# Accuracy of train set: tensor(0.9092, device='cuda:0')
# Epoch    52: reducing learning rate of group 0 to 2.0000e-05.
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 52 loss = 54.5716438293457
# Accuracy of train set: tensor(0.9107, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 53 loss = 54.37767028808594
# Accuracy of train set: tensor(0.9125, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 54 loss = 54.89518737792969
# Accuracy of train set: tensor(0.9071, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 55 loss = 55.36745834350586
# Accuracy of train set: tensor(0.9065, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 56 loss = 51.3854866027832
# Accuracy of train set: tensor(0.9196, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 57 loss = 54.5695686340332
# Accuracy of train set: tensor(0.9122, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 58 loss = 51.83356475830078
# Accuracy of train set: tensor(0.9110, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 59 loss = 56.89604949951172
# Accuracy of train set: tensor(0.9068, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 60 loss = 50.57478713989258
# Accuracy of train set: tensor(0.9208, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 61 loss = 53.26443862915039
# Accuracy of train set: tensor(0.9107, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 62 loss = 53.966094970703125
# Accuracy of train set: tensor(0.9160, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 63 loss = 53.34336853027344
# Accuracy of train set: tensor(0.9137, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 64 loss = 50.408294677734375
# Accuracy of train set: tensor(0.9155, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 65 loss = 55.834991455078125
# Accuracy of train set: tensor(0.9071, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 66 loss = 53.756202697753906
# Accuracy of train set: tensor(0.9143, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 67 loss = 54.28864669799805
# Accuracy of train set: tensor(0.9110, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 68 loss = 50.5928840637207
# Accuracy of train set: tensor(0.9169, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 69 loss = 52.3546142578125
# Accuracy of train set: tensor(0.9184, device='cuda:0')
# Epoch    70: reducing learning rate of group 0 to 2.0000e-06.
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 70 loss = 49.88715744018555
# Accuracy of train set: tensor(0.9166, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 71 loss = 55.038970947265625
# Accuracy of train set: tensor(0.9119, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 72 loss = 53.72478103637695
# Accuracy of train set: tensor(0.9097, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 73 loss = 55.83082962036133
# Accuracy of train set: tensor(0.9086, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 74 loss = 55.594696044921875
# Accuracy of train set: tensor(0.9152, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 75 loss = 52.49058151245117
# Accuracy of train set: tensor(0.9163, device='cuda:0')
# Epoch    76: reducing learning rate of group 0 to 2.0000e-07.
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 76 loss = 52.50053787231445
# Accuracy of train set: tensor(0.9146, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 77 loss = 53.291683197021484
# Accuracy of train set: tensor(0.9155, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 78 loss = 56.68301773071289
# Accuracy of train set: tensor(0.9092, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 79 loss = 52.88730239868164
# Accuracy of train set: tensor(0.9119, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 80 loss = 49.60914611816406
# Accuracy of train set: tensor(0.9214, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 81 loss = 54.76396942138672
# Accuracy of train set: tensor(0.9050, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 82 loss = 55.462745666503906
# Accuracy of train set: tensor(0.9056, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 83 loss = 56.2349967956543
# Accuracy of train set: tensor(0.9068, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 84 loss = 51.04631423950195
# Accuracy of train set: tensor(0.9155, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 85 loss = 52.704200744628906
# Accuracy of train set: tensor(0.9110, device='cuda:0')
# Epoch    86: reducing learning rate of group 0 to 2.0000e-08.
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 86 loss = 52.450172424316406
# Accuracy of train set: tensor(0.9149, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 87 loss = 53.18556594848633
# Accuracy of train set: tensor(0.9161, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 88 loss = 55.535640716552734
# Accuracy of train set: tensor(0.9104, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 89 loss = 52.9251708984375
# Accuracy of train set: tensor(0.9137, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 90 loss = 53.240257263183594
# Accuracy of train set: tensor(0.9104, device='cuda:0')
# Epoch    91: reducing learning rate of group 0 to 2.0000e-09.
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 91 loss = 54.49698257446289
# Accuracy of train set: tensor(0.9119, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 92 loss = 52.46919631958008
# Accuracy of train set: tensor(0.9142, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 93 loss = 56.6375617980957
# Accuracy of train set: tensor(0.9080, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 94 loss = 51.773983001708984
# Accuracy of train set: tensor(0.9116, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 95 loss = 54.208885192871094
# Accuracy of train set: tensor(0.9074, device='cuda:0')
# Epoch    96: reducing learning rate of group 0 to 2.0000e-10.
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 96 loss = 54.92463684082031
# Accuracy of train set: tensor(0.9065, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 97 loss = 48.973506927490234
# Accuracy of train set: tensor(0.9202, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 98 loss = 50.113258361816406
# Accuracy of train set: tensor(0.9175, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 99 loss = 53.49956130981445
# Accuracy of train set: tensor(0.9181, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 100 loss = 52.50703430175781
# Accuracy of train set: tensor(0.9142, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 101 loss = 55.700748443603516
# Accuracy of train set: tensor(0.9086, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 102 loss = 52.92070770263672
# Accuracy of train set: tensor(0.9092, device='cuda:0')
# Epoch   103: reducing learning rate of group 0 to 2.0000e-11.
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 103 loss = 55.29767608642578
# Accuracy of train set: tensor(0.9113, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 104 loss = 51.30638122558594
# Accuracy of train set: tensor(0.9131, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 105 loss = 51.52067565917969
# Accuracy of train set: tensor(0.9125, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 106 loss = 51.56605911254883
# Accuracy of train set: tensor(0.9163, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 107 loss = 56.43264389038086
# Accuracy of train set: tensor(0.9095, device='cuda:0')
# Epoch   108: reducing learning rate of group 0 to 2.0000e-12.
# Accuracy of validation set : tensor(0.9545, device='cuda:0')
# Iteration no: 108 loss = 53.986122131347656
# Accuracy of train set: tensor(0.9163, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 109 loss = 48.476707458496094
# Accuracy of train set: tensor(0.9196, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 110 loss = 56.405982971191406
# Accuracy of train set: tensor(0.9065, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 111 loss = 52.86335754394531
# Accuracy of train set: tensor(0.9149, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 112 loss = 48.32868194580078
# Accuracy of train set: tensor(0.9143, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 113 loss = 57.585941314697266
# Accuracy of train set: tensor(0.9074, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 114 loss = 58.701568603515625
# Accuracy of train set: tensor(0.9071, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 115 loss = 54.41722106933594
# Accuracy of train set: tensor(0.9085, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 116 loss = 52.50706481933594
# Accuracy of train set: tensor(0.9119, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 117 loss = 48.55704879760742
# Accuracy of train set: tensor(0.9190, device='cuda:0')
# Epoch   118: reducing learning rate of group 0 to 2.0000e-13.
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 118 loss = 55.14688491821289
# Accuracy of train set: tensor(0.9113, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 119 loss = 54.782222747802734
# Accuracy of train set: tensor(0.9107, device='cuda:0')
# Accuracy of validation set : tensor(0.9545, device='cuda:0')

# %%
torch.save(model, 'drive/My Drive/Colab Notebooks/ITSP/gest_full_resnet50.pth')
