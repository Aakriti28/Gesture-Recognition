# %%
import sys
import os
import torch
import cv2 as cv
import numpy as np
import torchvision
from torch import nn, optim
import torch.nn.functional as F
import torch.utils.data
import torchvision.datasets as dset
import torchvision.utils as vutils
from torch.utils.data import DataLoader
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import random
from torch.utils.data.sampler import SubsetRandomSampler
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Using GPU
print(sys.version)
device = 'cuda'
#Checking for GPU
print(torch.version.cuda)
print(torch.cuda.device_count())
print(torch.cuda.is_available())
# Out:
# 3.6.9 (default, Apr 18 2020, 01:56:04)
# [GCC 8.4.0]
# 10.1
# 1
# True

# %%
lookup = dict()
reverselookup = dict()

count = 0

for j in os.listdir('drive/My Drive/Colab Notebooks/ITSP/mydata/'):
    if not j.startswith('.'):
        lookup[j] = count
        reverselookup[count] = j
        count += 1
        
print(lookup)
print(reverselookup)
# Out:
# {'3': 0, '6': 1, '4': 2, '2': 3, '1': 4, '7': 5, '5': 6, '8': 7, '0': 8, '9': 9}
# {0: '3', 1: '6', 2: '4', 3: '2', 4: '1', 5: '7', 6: '5', 7: '8', 8: '0', 9: '9'}

# %%
x_data = []
y_data = []
datacount = 0
image_size = 256

dataset = dset.ImageFolder(root = 'drive/My Drive/Colab Notebooks/ITSP/mydata', 
                transform = 
                transforms.Compose([
                transforms.Resize(image_size),
                transforms.RandomResizedCrop(size=256, scale=(0.95, 1.0)),
                transforms.RandomRotation(degrees=10),
                transforms.ColorJitter(),
                transforms.RandomHorizontalFlip(0.4),
                transforms.Resize(size=224),  # Image net standards
                transforms.ToTensor(),
                transforms.Normalize([0.485, 0.456, 0.406],
                                     [0.229, 0.224, 0.225])  # Imagenet standards
                #transforms.ToTensor(), 
                #transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                ]))

print(dataset)

batch = 16
random_seed = random.randint(1, 100)

dataset_size = len(dataset)
split = int(0.05*dataset_size)
print('Size of dataset is: ', dataset_size)
print('Split value: ', split)
indices = list(range(dataset_size))

np.random.seed(random_seed)
np.random.shuffle(indices)

train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch, sampler=train_sampler,
                                            num_workers = 2)
valid_loader = torch.utils.data.DataLoader(dataset, batch_size=batch, sampler=valid_sampler,
                                            num_workers = 2)

print(len(train_loader))
print(len(valid_loader))


#for image, label in train_loader:
    #print(label)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 3535
#     Root location: drive/My Drive/Colab Notebooks/ITSP/mydata
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=PIL.Image.BILINEAR)
#                RandomResizedCrop(size=(256, 256), scale=(0.95, 1.0), ratio=(0.75, 1.3333), interpolation=PIL.Image.BILINEAR)
#                RandomRotation(degrees=(-10, 10), resample=False, expand=False)
#                ColorJitter(brightness=None, contrast=None, saturation=None, hue=None)
#                RandomHorizontalFlip(p=0.4)
#                Resize(size=224, interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# Size of dataset is:  3535
# Split value:  176
# 210
# 11

# %%
# Iterate through the dataloader once
trainiter = iter(train_loader)
features, labels = next(trainiter)
features.shape, labels.shape
# Out:
# (torch.Size([16, 3, 224, 224]), torch.Size([16]))

# %%
def get_image_shape():
    img = cv.imread('drive/My Drive/Colab Notebooks/ITSP/mydata/1/1.jpg', 0)
    return img.shape


img_shape = get_image_shape()
print('Image shape: ', img_shape)
root = 'drive/My Drive/Colab Notebooks/ITSP/mydata'
gesture_data = os.listdir(root)
num_g = len(gesture_data)
print('Number of gestures: ', num_g)
num_rows = int(num_g/4)

if(num_g%4):
   num_rows+=1

print('Number of rows: ', num_rows)

begin = 0
final_img = None

for i in range(num_rows):
    row_img = None
    for j in range(begin, begin+4):
        if (j>= num_g):
            img = np.zeros(img_shape, dtype = np.uint8)
            #print('Image index: ', j, 'false')
            
        else:         
            imgpath = root + '/' + reverselookup[j] + '/' + str(random.randint(1, 200)) + '.jpg'
            img = cv.imread(imgpath, 0)
            #if not np.any(img == None):
                #print('Image index: ', j, 'true')
            
        if np.any(row_img == None):
            row_img = img
        else:
            row_img = np.hstack((row_img, img))
            
    begin += 4
    if np.any(final_img == None):
            final_img = row_img
    else:
        final_img = np.vstack((final_img, row_img))  
                        
plt.imshow(final_img, cmap='gray')
#cv.waitKey(0)
#cv.destroyAllWindows()
# Out:
# Image shape:  (256, 256)
# Number of gestures:  10
# Number of rows:  3

# %%
gestures = []
titles = []

for i in range(num_g):
    imgpath = root + '/' + reverselookup[i] + '/' + str(random.randint(1, 200)) + '.jpg'
    img = cv.imread(imgpath, 0)
    gestures.append(img)
    titles.append(reverselookup[i])
    
for i in range(num_g):
    plt.subplot(3, 4, i+1)
    plt.imshow(gestures[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

# %%
from torchvision import models
model = models.resnext50_32x4d(pretrained=True)
for param in model.parameters():
    param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/resnext50_32x4d-7cdf4587.pth" to /root/.cache/torch/checkpoints/resnext50_32x4d-7cdf4587.pth
# HBox(children=(FloatProgress(value=0.0, max=100441675.0), HTML(value='')))

# %%
torch.save(model, 'drive/My Drive/Colab Notebooks/ITSP/weights3.pth')
print(model)
# Out:
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=512, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Dropout(p=0.1, inplace=False)
#       (5): Linear(in_features=256, out_features=10, bias=True)
#       (6): LogSoftmax()
#     )
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Dropout(p=0.1, inplace=False)
#     (5): Linear(in_features=128, out_features=10, bias=True)
#     (6): LogSoftmax()
#   )
# )

# %%
n_classes = 10

model.fc = nn.Sequential(
                      nn.Linear(2048, 512), 
                      nn.ReLU(), 
                      nn.Linear(512, 128), 
                      nn.ReLU(),
                      nn.Dropout(0.3), 
                      nn.Linear(128, n_classes),                   
                      nn.LogSoftmax(dim=1))

print(model)
# Out:
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=512, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Dropout(p=0.1, inplace=False)
#       (5): Linear(in_features=256, out_features=10, bias=True)
#       (6): LogSoftmax()
#     )
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Dropout(p=0.3, inplace=False)
#     (5): Linear(in_features=128, out_features=10, bias=True)
#     (6): LogSoftmax()
#   )
# )

# %%
total_params = sum(p.numel() for p in model.parameters())

print(f'{total_params:,} total parameters')

total_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'{total_trainable:,} trainable parameters.')
# Out:
# 25,278,932 total parameters
# 2,299,028 trainable parameters.

# %%
# Move to gpu
model = model.to('cuda')
# Distribute across 2 gpus
model = nn.DataParallel(model)

loss_func = F.cross_entropy
optimizer = optim.Adam(model.parameters(), betas=(0.8, 0.99), lr = 0.002)

# %%
def accuracy(out, yb):
    pred = torch.argmax(out, keepdim= False, dim=1)
    return (pred == yb).float().mean()

# %%
def fit(model, epochs, train_loader, valid_loader, opt):
    losses = []
    
    for epoch in range(epochs):
        train_loss =0
        train_acc =0
        model.train()
        for xb, yb in train_loader:
            xb =xb.to(device)
            yb = yb.to(device)
            pred = model(xb.float())
            pred.to(device)
            train_acc += accuracy(pred, yb)
            loss = loss_func(pred, yb)
            train_loss += loss
            #back propogation
            loss.backward()
            opt.step()
            opt.zero_grad()      

        losses.append(train_loss)
        print("Iteration no: "+ str(epoch), "loss = "+str(losses[epoch].item()))
        print("Accuracy of train set:", train_acc/len(train_loader))
        lr_scheduler.step(train_loss/len(train_loader))
        
        
        model.eval()    
        with torch.no_grad():
            valid_acc=0
            loss_valid = 0
            for xb_valid, yb_valid in valid_loader:
                xb_valid = xb_valid.to(device)
                yb_valid = yb_valid.to(device)
                pred_valid = model(xb_valid.float())
                pred_valid.to(device)
                valid_acc += accuracy(pred_valid, yb_valid)
                loss_valid += loss_func(pred_valid, yb_valid)
            print("Accuracy of validation set :", valid_acc/len(valid_loader))

    plt.plot(losses)
    plt.ylabel("loss")
    plt.xlabel("iterations")
    plt.show()

# %%
lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=4, verbose=True, eps = 10e-14)

fit(model, 100, train_loader, valid_loader, optimizer)
# Out:
# Iteration no: 0 loss = 299.1510314941406
# Accuracy of train set: tensor(0.4666, device='cuda:0')
# Accuracy of validation set : tensor(0.6989, device='cuda:0')
# Iteration no: 1 loss = 161.3588409423828
# Accuracy of train set: tensor(0.7172, device='cuda:0')
# Accuracy of validation set : tensor(0.7557, device='cuda:0')
# Iteration no: 2 loss = 145.20884704589844
# Accuracy of train set: tensor(0.7539, device='cuda:0')
# Accuracy of validation set : tensor(0.8409, device='cuda:0')
# Iteration no: 3 loss = 125.08710479736328
# Accuracy of train set: tensor(0.7872, device='cuda:0')
# Iteration no: 44 loss = 73.40335083007812
# Accuracy of train set: tensor(0.8803, device='cuda:0')
# Accuracy of validation set : tensor(0.8920, device='cuda:0')
# Iteration no: 45 loss = 77.7223892211914
# Accuracy of train set: tensor(0.8797, device='cuda:0')
# Accuracy of validation set : tensor(0.8864, device='cuda:0')
# Iteration no: 46 loss = 75.99044036865234
# Accuracy of train set: tensor(0.8792, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 47 loss = 83.6795883178711
# Accuracy of train set: tensor(0.8663, device='cuda:0')
# Accuracy of validation set : tensor(0.8864, device='cuda:0')
# Iteration no: 48 loss = 74.17304229736328
# Accuracy of train set: tensor(0.8800, device='cuda:0')
# Epoch    49: reducing learning rate of group 0 to 2.0000e-04.
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 49 loss = 59.133056640625
# Accuracy of train set: tensor(0.9065, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 50 loss = 56.71470642089844
# Accuracy of train set: tensor(0.9059, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 51 loss = 58.28997802734375
# Accuracy of train set: tensor(0.9076, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 52 loss = 50.800880432128906
# Accuracy of train set: tensor(0.9175, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 53 loss = 57.55583190917969
# Accuracy of train set: tensor(0.9059, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 54 loss = 50.24972915649414
# Accuracy of train set: tensor(0.9199, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 55 loss = 54.35456466674805
# Accuracy of train set: tensor(0.9086, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 56 loss = 46.628658294677734
# Accuracy of train set: tensor(0.9208, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 57 loss = 51.296836853027344
# Accuracy of train set: tensor(0.9190, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 58 loss = 48.578712463378906
# Accuracy of train set: tensor(0.9187, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 59 loss = 56.48262023925781
# Accuracy of train set: tensor(0.9026, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 60 loss = 49.43299865722656
# Accuracy of train set: tensor(0.9175, device='cuda:0')
# Accuracy of validation set : tensor(0.8920, device='cuda:0')
# Iteration no: 61 loss = 50.54452133178711
# Accuracy of train set: tensor(0.9175, device='cuda:0')
# Epoch    62: reducing learning rate of group 0 to 2.0000e-05.
# Accuracy of validation set : tensor(0.8920, device='cuda:0')
# Iteration no: 62 loss = 48.06977081298828
# Accuracy of train set: tensor(0.9208, device='cuda:0')
# Accuracy of validation set : tensor(0.8920, device='cuda:0')
# Iteration no: 63 loss = 52.20069122314453
# Accuracy of train set: tensor(0.9172, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 64 loss = 48.527889251708984
# Accuracy of train set: tensor(0.9196, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 65 loss = 50.59214782714844
# Accuracy of train set: tensor(0.9125, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 66 loss = 48.06953430175781
# Accuracy of train set: tensor(0.9217, device='cuda:0')
# Epoch    67: reducing learning rate of group 0 to 2.0000e-06.
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 67 loss = 48.52111053466797
# Accuracy of train set: tensor(0.9217, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 68 loss = 52.97163772583008
# Accuracy of train set: tensor(0.9119, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 69 loss = 47.414066314697266
# Accuracy of train set: tensor(0.9256, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 70 loss = 44.493560791015625
# Accuracy of train set: tensor(0.9244, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 71 loss = 52.352386474609375
# Accuracy of train set: tensor(0.9122, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 72 loss = 49.43619155883789
# Accuracy of train set: tensor(0.9170, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 73 loss = 50.40041732788086
# Accuracy of train set: tensor(0.9202, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 74 loss = 49.5703125
# Accuracy of train set: tensor(0.9179, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 75 loss = 48.78083801269531
# Accuracy of train set: tensor(0.9164, device='cuda:0')
# Epoch    76: reducing learning rate of group 0 to 2.0000e-07.
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 76 loss = 47.842262268066406
# Accuracy of train set: tensor(0.9205, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 77 loss = 46.13380813598633
# Accuracy of train set: tensor(0.9220, device='cuda:0')
# Accuracy of validation set : tensor(0.8807, device='cuda:0')
# Iteration no: 78 loss = 49.884849548339844
# Accuracy of train set: tensor(0.9155, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 79 loss = 45.65226364135742
# Accuracy of train set: tensor(0.9190, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 80 loss = 48.36082458496094
# Accuracy of train set: tensor(0.9223, device='cuda:0')
# Epoch    81: reducing learning rate of group 0 to 2.0000e-08.
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 81 loss = 51.57435607910156
# Accuracy of train set: tensor(0.9152, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 82 loss = 48.87374496459961
# Accuracy of train set: tensor(0.9217, device='cuda:0')
# Accuracy of validation set : tensor(0.8636, device='cuda:0')
# Iteration no: 83 loss = 47.447364807128906
# Accuracy of train set: tensor(0.9199, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 84 loss = 47.17301559448242
# Accuracy of train set: tensor(0.9220, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 85 loss = 49.225921630859375
# Accuracy of train set: tensor(0.9179, device='cuda:0')
# Epoch    86: reducing learning rate of group 0 to 2.0000e-09.
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 86 loss = 48.18558883666992
# Accuracy of train set: tensor(0.9205, device='cuda:0')
# Accuracy of validation set : tensor(0.8864, device='cuda:0')
# Iteration no: 87 loss = 49.67295455932617
# Accuracy of train set: tensor(0.9190, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 88 loss = 50.68153762817383
# Accuracy of train set: tensor(0.9184, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 89 loss = 49.86277389526367
# Accuracy of train set: tensor(0.9122, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 90 loss = 53.69975280761719
# Accuracy of train set: tensor(0.9115, device='cuda:0')
# Epoch    91: reducing learning rate of group 0 to 2.0000e-10.
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 91 loss = 48.866458892822266
# Accuracy of train set: tensor(0.9222, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 92 loss = 42.208251953125
# Accuracy of train set: tensor(0.9285, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 93 loss = 52.2353401184082
# Accuracy of train set: tensor(0.9181, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 94 loss = 48.987342834472656
# Accuracy of train set: tensor(0.9161, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 95 loss = 52.92630386352539
# Accuracy of train set: tensor(0.9155, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 96 loss = 46.001129150390625
# Accuracy of train set: tensor(0.9223, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 97 loss = 49.99923324584961
# Accuracy of train set: tensor(0.9181, device='cuda:0')
# Epoch    98: reducing learning rate of group 0 to 2.0000e-11.
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 98 loss = 48.08443832397461
# Accuracy of train set: tensor(0.9196, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 99 loss = 50.87207794189453
# Accuracy of train set: tensor(0.9185, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 100 loss = 48.01695251464844
# Accuracy of train set: tensor(0.9190, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 101 loss = 45.728267669677734
# Accuracy of train set: tensor(0.9253, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 102 loss = 49.50766372680664
# Accuracy of train set: tensor(0.9205, device='cuda:0')
# Epoch   103: reducing learning rate of group 0 to 2.0000e-12.
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 103 loss = 51.959503173828125
# Accuracy of train set: tensor(0.9148, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 104 loss = 46.97679138183594
# Accuracy of train set: tensor(0.9226, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 105 loss = 46.58148193359375
# Accuracy of train set: tensor(0.9202, device='cuda:0')
# Accuracy of validation set : tensor(0.9489, device='cuda:0')
# Iteration no: 106 loss = 50.06015396118164
# Accuracy of train set: tensor(0.9208, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 107 loss = 44.87633514404297
# Accuracy of train set: tensor(0.9199, device='cuda:0')
# Epoch   108: reducing learning rate of group 0 to 2.0000e-13.
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 108 loss = 49.73258972167969
# Accuracy of train set: tensor(0.9155, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 109 loss = 50.01541519165039
# Accuracy of train set: tensor(0.9161, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 110 loss = 44.94295120239258
# Accuracy of train set: tensor(0.9280, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 111 loss = 49.49456024169922
# Accuracy of train set: tensor(0.9226, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 112 loss = 46.82044982910156
# Accuracy of train set: tensor(0.9185, device='cuda:0')
# Epoch   113: reducing learning rate of group 0 to 2.0000e-14.
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 113 loss = 50.362205505371094
# Accuracy of train set: tensor(0.9170, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 114 loss = 52.95058059692383
# Accuracy of train set: tensor(0.9083, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 115 loss = 50.96815872192383
# Accuracy of train set: tensor(0.9119, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 116 loss = 52.36693572998047
# Accuracy of train set: tensor(0.9103, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 117 loss = 52.706233978271484
# Accuracy of train set: tensor(0.9151, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 118 loss = 49.89519119262695
# Accuracy of train set: tensor(0.9178, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 119 loss = 49.05925369262695
# Accuracy of train set: tensor(0.9208, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 120 loss = 52.18800735473633
# Accuracy of train set: tensor(0.9252, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 141 loss = 48.118408203125
# Accuracy of train set: tensor(0.9217, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 142 loss = 51.525001525878906
# Accuracy of train set: tensor(0.9169, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 143 loss = 48.65641784667969
# Accuracy of train set: tensor(0.9262, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 144 loss = 48.03578186035156
# Accuracy of train set: tensor(0.9211, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 145 loss = 50.49220275878906
# Accuracy of train set: tensor(0.9184, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 146 loss = 49.60886001586914
# Accuracy of train set: tensor(0.9161, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 147 loss = 51.93879318237305
# Accuracy of train set: tensor(0.9151, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 148 loss = 47.8828125
# Accuracy of train set: tensor(0.9232, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 149 loss = 47.73073196411133
# Accuracy of train set: tensor(0.9211, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 150 loss = 44.932159423828125
# Accuracy of train set: tensor(0.9211, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 151 loss = 50.995460510253906
# Accuracy of train set: tensor(0.9152, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 152 loss = 56.06416702270508
# Accuracy of train set: tensor(0.9086, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 153 loss = 49.44978713989258
# Accuracy of train set: tensor(0.9232, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 154 loss = 50.273860931396484
# Accuracy of train set: tensor(0.9166, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 155 loss = 50.14059829711914
# Accuracy of train set: tensor(0.9175, device='cuda:0')
# Accuracy of validation set : tensor(0.8920, device='cuda:0')
# Iteration no: 156 loss = 46.23628234863281
# Accuracy of train set: tensor(0.9223, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 157 loss = 55.85439682006836
# Accuracy of train set: tensor(0.9131, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 158 loss = 50.78128433227539
# Accuracy of train set: tensor(0.9211, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 159 loss = 48.10758972167969
# Accuracy of train set: tensor(0.9185, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 160 loss = 49.57109832763672
# Accuracy of train set: tensor(0.9226, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 161 loss = 50.732421875
# Accuracy of train set: tensor(0.9143, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 162 loss = 48.338958740234375
# Accuracy of train set: tensor(0.9196, device='cuda:0')
# Accuracy of validation set : tensor(0.9602, device='cuda:0')
# Iteration no: 163 loss = 49.536720275878906
# Accuracy of train set: tensor(0.9164, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 164 loss = 53.960243225097656
# Accuracy of train set: tensor(0.9095, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')
# Iteration no: 165 loss = 48.86826705932617
# Accuracy of train set: tensor(0.9223, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 166 loss = 48.009334564208984
# Accuracy of train set: tensor(0.9190, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 167 loss = 50.911231994628906
# Accuracy of train set: tensor(0.9208, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 168 loss = 47.0440559387207
# Accuracy of train set: tensor(0.9208, device='cuda:0')
# Accuracy of validation set : tensor(0.9432, device='cuda:0')
# Iteration no: 169 loss = 51.102455139160156
# Accuracy of train set: tensor(0.9134, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 170 loss = 51.08602523803711
# Accuracy of train set: tensor(0.9110, device='cuda:0')
# Accuracy of validation set : tensor(0.9091, device='cuda:0')
# Iteration no: 171 loss = 48.85268020629883
# Accuracy of train set: tensor(0.9155, device='cuda:0')
# Accuracy of validation set : tensor(0.9261, device='cuda:0')
# Iteration no: 172 loss = 47.61795425415039
# Accuracy of train set: tensor(0.9247, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 173 loss = 46.16553497314453
# Accuracy of train set: tensor(0.9213, device='cuda:0')
# Accuracy of validation set : tensor(0.9318, device='cuda:0')
# Iteration no: 174 loss = 51.67767333984375
# Accuracy of train set: tensor(0.9137, device='cuda:0')
# Accuracy of validation set : tensor(0.9375, device='cuda:0')
# Iteration no: 175 loss = 46.3729133605957
# Accuracy of train set: tensor(0.9297, device='cuda:0')
# Accuracy of validation set : tensor(0.9205, device='cuda:0')
# Iteration no: 176 loss = 50.86021041870117
# Accuracy of train set: tensor(0.9163, device='cuda:0')
# Accuracy of validation set : tensor(0.9148, device='cuda:0')
# Iteration no: 177 loss = 45.822608947753906
# Accuracy of train set: tensor(0.9202, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 178 loss = 49.98491668701172
# Accuracy of train set: tensor(0.9158, device='cuda:0')
# Accuracy of validation set : tensor(0.9034, device='cuda:0')
# Iteration no: 179 loss = 53.03575897216797
# Accuracy of train set: tensor(0.9134, device='cuda:0')
# Accuracy of validation set : tensor(0.8977, device='cuda:0')

# %%
torch.save(model, 'drive/My Drive/Colab Notebooks/ITSP/gest_full_resnext50_32x4d.pth')
